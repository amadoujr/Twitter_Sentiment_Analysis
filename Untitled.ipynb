# %%
import pandas as pd

# %%
file = pd.read_csv('covid.csv',sep=";")

# %%
file
# Out:
#       0  0460442002960940484  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown  \
# 0     2         4.828964e+17  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown
# 1     2         4.756744e+17  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown
# 2     0         4.804009e+17  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown
# 3     4         4.620656e+17  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown
# 4     0         4.502851e+17  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown
# ...  ..                  ...                           ...      ...      ...
# 5994  2         4.709751e+17  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown
# 5995  4         4.798271e+17  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown
# 5996  2         4.847895e+17  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown
# 5997  0         4.824551e+17  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown
# 5998  2         4.800505e+17  Mon Apr 06 22:19:45 PDT 2023  COVID19  Unkwown
#
# ...
